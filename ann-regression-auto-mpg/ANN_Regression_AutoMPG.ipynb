# %% [markdown]
# # 🚗 Fuel Efficiency (MPG) Regression with a Feed-Forward Neural Network
#
# Predicts a car's fuel efficiency (miles per gallon) from its specs, using a small feed-forward ANN (Keras/TensorFlow).
#
# **Dataset:** [Auto MPG](https://www.kaggle.com/datasets/uciml/autompg-dataset) (also known as the classic UCI Auto MPG dataset) — 398 cars with `mpg`, `cylinders`, `displacement`, `horsepower`, `weight`, `acceleration`, `model year`, `origin`, and `car name`.
#
# **Approach:** clean the data (fix the `horsepower` dtype, one-hot the `origin` country), z-score normalize all features, then train a 3-hidden-layer ReLU network (16 units each) with early stopping, LR reduction on plateau, and best-checkpoint saving.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Explanation for the dataset:
#
# 1. **mpg**: Fuel efficiency in miles per gallon.
# 2. **cylinders**: Number of engine cylinders.
# 3. **displacement**: Engine size, typically in cubic inches or liters.
# 4. **horsepower**: Engine power output.
# 5. **weight**: Car’s weight in pounds or kilograms.
# 6. **acceleration**: Time to go from 0 to 60 mph.
# 7. **model year**: Year the car model was released.
# 8. **origin**: Country/region of manufacture.
# 9. **car name**: Brand and model of the car.

# %% [markdown]
# **IMPORTING LIBRARIES**

# %%
# !pip install tensorflow
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras.models import Sequential
from keras.layers import Dense
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.0)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (13.8.0)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.0.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.17.0

# %% [markdown]
# **LOAD DATASET**

# %%
data=pd.read_csv('auto-mpg.csv')
data
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# 1            70       1          buick skylark 320
# 2            70       1         plymouth satellite
# 3            70       1              amc rebel sst
# 4            70       1                ford torino
# ..          ...     ...                        ...
# 393          82       1            ford mustang gl
# 394          82       2                  vw pickup
# 395          82       1              dodge rampage
# 396          82       1                ford ranger
# 397          82       1                 chevy s-10
#
# [398 rows x 9 columns]

# %%
data=data.drop(columns=['car name'])
data
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin
# 0            70       1
# 1            70       1
# 2            70       1
# 3            70       1
# 4            70       1
# ..          ...     ...
# 393          82       1
# 394          82       2
# 395          82       1
# 396          82       1
# 397          82       1
#
# [398 rows x 8 columns]

# %% [markdown]
# Here we convert the origin country which is a categorical column to numerical taking UK=1, EUROPE=2 and USA=3.

# %%
origin=data.pop('origin')
data['uk']=(origin==1)*1
data['europe']=(origin==2)*2
data['usa']=(origin==3)*3
data
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  uk  europe  usa
# 0            70   1       0    0
# 1            70   1       0    0
# 2            70   1       0    0
# 3            70   1       0    0
# 4            70   1       0    0
# ..          ...  ..     ...  ...
# 393          82   1       0    0
# 394          82   0       2    0
# 395          82   1       0    0
# 396          82   1       0    0
# 397          82   1       0    0
#
# [398 rows x 10 columns]

# %%
data.shape
# Out:
# (398, 10)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   uk            398 non-null    int64
#  8   europe        398 non-null    int64
#  9   usa           398 non-null    int64
# dtypes: float64(3), int64(6), object(1)
# memory usage: 31.2+ KB

# %%
data['horsepower'].unique()
# Out:
# array(['130', '165', '150', '140', '198', '220', '215', '225', '190',
#        '170', '160', '95', '97', '85', '88', '46', '87', '90', '113',
#        '200', '210', '193', '?', '100', '105', '175', '153', '180', '110',
#        '72', '86', '70', '76', '65', '69', '60', '80', '54', '208', '155',
#        '112', '92', '145', '137', '158', '167', '94', '107', '230', '49',
#        '75', '91', '122', '67', '83', '78', '52', '61', '93', '148',
#        '129', '96', '71', '98', '115', '53', '81', '79', '120', '152',
#        '102', '108', '68', '58', '149', '89', '63', '48', '66', '139',
#        '103', '125', '133', '138', '135', '142', '77', '62', '132', '84',
#        '64', '74', '116', '82'], dtype=object)

# %%
data['horsepower']=data['horsepower'].replace('?',0)
data['horsepower'] = data['horsepower'].astype('int')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    int64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   uk            398 non-null    int64
#  8   europe        398 non-null    int64
#  9   usa           398 non-null    int64
# dtypes: float64(3), int64(7)
# memory usage: 31.2 KB

# %% [markdown]
# Splitted the complete dataset into train and test data in the fraction of 80:20

# %% [markdown]
# Basic Statistics of the train dataset

# %%
train_data_state=data.describe().T
train_data_state
# Out:
#               count         mean         std     min       25%     50%  \
# mpg           398.0    23.514573    7.815984     9.0    17.500    23.0
# cylinders     398.0     5.454774    1.701004     3.0     4.000     4.0
# displacement  398.0   193.425879  104.269838    68.0   104.250   148.5
# horsepower    398.0   102.894472   40.269544     0.0    75.000    92.0
# weight        398.0  2970.424623  846.841774  1613.0  2223.750  2803.5
# acceleration  398.0    15.568090    2.757689     8.0    13.825    15.5
# model year    398.0    76.010050    3.697627    70.0    73.000    76.0
# uk            398.0     0.625628    0.484569     0.0     0.000     1.0
# europe        398.0     0.351759    0.762393     0.0     0.000     0.0
# usa           398.0     0.595477    1.198101     0.0     0.000     0.0
#
#                    75%     max
# mpg             29.000    46.6
# cylinders        8.000     8.0
# displacement   262.000   455.0
# horsepower     125.000   230.0
# weight        3608.000  5140.0
# acceleration    17.175    24.8
# model year      79.000    82.0
# uk               1.000     1.0
# europe           0.000     2.0
# usa              0.000     3.0

# %% [markdown]
# As we see in the basic statistics of dataset, all the columns in different scales, here we normalize data using z-score normalization.

# %%
# Standard scaler for the train_data['mpg']

import numpy as np
from sklearn.preprocessing import StandardScaler
scaler1 = StandardScaler()
data['mpg'] = scaler1.fit_transform(np.array(data['mpg']).reshape(-1, 1))

# %%
data['mpg']
# Out:
# 0     -0.706439
# 1     -1.090751
# 2     -0.706439
# 3     -0.962647
# 4     -0.834543
#          ...
# 393    0.446497
# 394    2.624265
# 395    1.087017
# 396    0.574601
# 397    0.958913
# Name: mpg, Length: 398, dtype: float64

# %%
# prompt: standard scaler for all features except mpg
scaler2 = StandardScaler()
data[['cylinders', 'displacement', 'horsepower', 'weight',
       'acceleration', 'model year', 'uk', 'europe', 'usa']] = scaler2.fit_transform(data[['cylinders', 'displacement', 'horsepower', 'weight',
       'acceleration', 'model year', 'uk', 'europe', 'usa']])

# %%
y=data['mpg']
X=data.drop(columns=['mpg'])

# %% [markdown]
# Train test split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y, test_size=0.2)

# %% [markdown]
# BUILD THE MODEL-
# Building of a feed forward neural network with Two hidden layers and one output layer with 16 units in the hidden layers and using relu activation function as the non-linear activation function. Optimizer used in this model is RMSprop which is used in general for the model of regression.

# %%
# linear , swish, relu, gelu, tanh, sigmoid, softmax

def build_model():
    model=keras.Sequential([layers.Dense(16, activation='relu'),
                            layers.Dense(16, activation='relu'),
                            layers.Dense(16, activation='relu'),
                                                 layers.Dense(1)])

    #optimizer=tf.keras.optimizers.RMSprop(0.001)
    model.compile(loss='mse', optimizer='adam', metrics=['mae','mse'])
    return model

# %%
model=build_model()

# %% [markdown]
# Converting the Features and labels of the dataset to numpy array to feed into the network.

# %%
# prompt: checkpoint early stopping, reduce on plateue, save best model

from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

# Define callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=20)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=7, min_lr=0.0001)
model_checkpoint = ModelCheckpoint('mpg_regressor.keras', monitor='val_loss', save_best_only=True)

# Train the model with callbacks
history = model.fit(
    X_train,
    y_train,
    epochs=5000,
    validation_split=0.1,
    callbacks=[early_stopping, reduce_lr, model_checkpoint], verbose=1
)
# Out:
# Epoch 1/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 154ms/step - loss: 1.1915 - mae: 0.9038 - mse: 1.1915 - val_loss: 1.3164 - val_mae: 0.9625 - val_mse: 1.3164 - learning_rate: 0.0010
# Epoch 2/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 0.9460 - mae: 0.8027 - mse: 0.9460 - val_loss: 1.0181 - val_mae: 0.8428 - val_mse: 1.0181 - learning_rate: 0.0010
# Epoch 3/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.7679 - mae: 0.7293 - mse: 0.7679 - val_loss: 0.7911 - val_mae: 0.7396 - val_mse: 0.7911 - learning_rate: 0.0010
# Epoch 4/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.5405 - mae: 0.6001 - mse: 0.5405 - val_loss: 0.6060 - val_mae: 0.6390 - val_mse: 0.6060 - learning_rate: 0.0010
# Epoch 5/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.4749 - mae: 0.5408 - mse: 0.4749 - val_loss: 0.4583 - val_mae: 0.5433 - val_mse: 0.4583 - learning_rate: 0.0010
# Epoch 6/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.3328 - mae: 0.4601 - mse: 0.3328 - val_loss: 0.3475 - val_mae: 0.4629 - val_mse: 0.3475 - learning_rate: 0.0010
# Epoch 7/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.2696 - mae: 0.3929 - mse: 0.2696 - val_loss: 0.2777 - val_mae: 0.3999 - val_mse: 0.2777 - learning_rate: 0.0010
# Epoch 8/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.2720 - mae: 0.3783 - mse: 0.2720 - val_loss: 0.2361 - val_mae: 0.3680 - val_mse: 0.2361 - learning_rate: 0.0010
# Epoch 9/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.2278 - mae: 0.3485 - mse: 0.2278 - val_loss: 0.2063 - val_mae: 0.3457 - val_mse: 0.2063 - learning_rate: 0.0010
# Epoch 10/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2144 - mae: 0.3492 - mse: 0.2144 - val_loss: 0.1870 - val_mae: 0.3322 - val_mse: 0.1870 - learning_rate: 0.0010
# Epoch 11/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.2441 - mae: 0.3612 - mse: 0.2441 - val_loss: 0.1714 - val_mae: 0.3185 - val_mse: 0.1714 - learning_rate: 0.0010
# Epoch 12/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.2356 - mae: 0.3431 - mse: 0.2356 - val_loss: 0.1564 - val_mae: 0.3050 - val_mse: 0.1564 - learning_rate: 0.0010
# Epoch 13/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1889 - mae: 0.3161 - mse: 0.1889 - val_loss: 0.1437 - val_mae: 0.2934 - val_mse: 0.1437 - learning_rate: 0.0010
# Epoch 14/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.1935 - mae: 0.3271 - mse: 0.1935 - val_loss: 0.1301 - val_mae: 0.2806 - val_mse: 0.1301 - learning_rate: 0.0010
# Epoch 15/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.1711 - mae: 0.3035 - mse: 0.1711 - val_loss: 0.1239 - val_mae: 0.2742 - val_mse: 0.1239 - learning_rate: 0.0010
# Epoch 16/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.1585 - mae: 0.2974 - mse: 0.1585 - val_loss: 0.1183 - val_mae: 0.2677 - val_mse: 0.1183 - learning_rate: 0.0010
# Epoch 17/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1589 - mae: 0.3039 - mse: 0.1589 - val_loss: 0.1127 - val_mae: 0.2610 - val_mse: 0.1127 - learning_rate: 0.0010
# Epoch 18/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1633 - mae: 0.2804 - mse: 0.1633 - val_loss: 0.1074 - val_mae: 0.2554 - val_mse: 0.1074 - learning_rate: 0.0010
# Epoch 19/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1713 - mae: 0.3007 - mse: 0.1713 - val_loss: 0.1014 - val_mae: 0.2509 - val_mse: 0.1014 - learning_rate: 0.0010
# Epoch 20/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1597 - mae: 0.2781 - mse: 0.1597 - val_loss: 0.0970 - val_mae: 0.2437 - val_mse: 0.0970 - learning_rate: 0.0010
# Epoch 21/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1501 - mae: 0.2864 - mse: 0.1501 - val_loss: 0.0946 - val_mae: 0.2407 - val_mse: 0.0946 - learning_rate: 0.0010
# Epoch 22/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1600 - mae: 0.2954 - mse: 0.1600 - val_loss: 0.0888 - val_mae: 0.2379 - val_mse: 0.0888 - learning_rate: 0.0010
# Epoch 23/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1562 - mae: 0.2817 - mse: 0.1562 - val_loss: 0.0865 - val_mae: 0.2362 - val_mse: 0.0865 - learning_rate: 0.0010
# Epoch 24/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1675 - mae: 0.2950 - mse: 0.1675 - val_loss: 0.0862 - val_mae: 0.2337 - val_mse: 0.0862 - learning_rate: 0.0010
# Epoch 25/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1298 - mae: 0.2649 - mse: 0.1298 - val_loss: 0.0827 - val_mae: 0.2310 - val_mse: 0.0827 - learning_rate: 0.0010
# Epoch 26/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.1412 - mae: 0.2624 - mse: 0.1412 - val_loss: 0.0804 - val_mae: 0.2313 - val_mse: 0.0804 - learning_rate: 0.0010
# Epoch 27/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1436 - mae: 0.2795 - mse: 0.1436 - val_loss: 0.0792 - val_mae: 0.2280 - val_mse: 0.0792 - learning_rate: 0.0010
# Epoch 28/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1403 - mae: 0.2684 - mse: 0.1403 - val_loss: 0.0785 - val_mae: 0.2282 - val_mse: 0.0785 - learning_rate: 0.0010
# Epoch 29/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.1381 - mae: 0.2725 - mse: 0.1381 - val_loss: 0.0767 - val_mae: 0.2261 - val_mse: 0.0767 - learning_rate: 0.0010
# Epoch 30/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.1412 - mae: 0.2666 - mse: 0.1412 - val_loss: 0.0749 - val_mae: 0.2236 - val_mse: 0.0749 - learning_rate: 0.0010
# Epoch 31/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.1074 - mae: 0.2415 - mse: 0.1074 - val_loss: 0.0746 - val_mae: 0.2232 - val_mse: 0.0746 - learning_rate: 0.0010
# Epoch 32/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.1175 - mae: 0.2500 - mse: 0.1175 - val_loss: 0.0723 - val_mae: 0.2223 - val_mse: 0.0723 - learning_rate: 0.0010
# Epoch 33/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.1345 - mae: 0.2744 - mse: 0.1345 - val_loss: 0.0719 - val_mae: 0.2219 - val_mse: 0.0719 - learning_rate: 0.0010
# Epoch 34/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 0.1322 - mae: 0.2607 - mse: 0.1322 - val_loss: 0.0714 - val_mae: 0.2219 - val_mse: 0.0714 - learning_rate: 0.0010
# Epoch 35/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.1339 - mae: 0.2624 - mse: 0.1339 - val_loss: 0.0720 - val_mae: 0.2189 - val_mse: 0.0720 - learning_rate: 0.0010
# Epoch 36/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.1228 - mae: 0.2508 - mse: 0.1228 - val_loss: 0.0712 - val_mae: 0.2223 - val_mse: 0.0712 - learning_rate: 0.0010
# Epoch 37/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.1345 - mae: 0.2611 - mse: 0.1345 - val_loss: 0.0705 - val_mae: 0.2219 - val_mse: 0.0705 - learning_rate: 0.0010
# Epoch 38/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.1302 - mae: 0.2634 - mse: 0.1302 - val_loss: 0.0704 - val_mae: 0.2170 - val_mse: 0.0704 - learning_rate: 0.0010
# Epoch 39/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.1282 - mae: 0.2508 - mse: 0.1282 - val_loss: 0.0706 - val_mae: 0.2217 - val_mse: 0.0706 - learning_rate: 0.0010
# Epoch 40/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1448 - mae: 0.2727 - mse: 0.1448 - val_loss: 0.0710 - val_mae: 0.2233 - val_mse: 0.0710 - learning_rate: 0.0010
# Epoch 41/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.1132 - mae: 0.2463 - mse: 0.1132 - val_loss: 0.0691 - val_mae: 0.2174 - val_mse: 0.0691 - learning_rate: 0.0010
# Epoch 42/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.1173 - mae: 0.2418 - mse: 0.1173 - val_loss: 0.0704 - val_mae: 0.2216 - val_mse: 0.0704 - learning_rate: 0.0010
# Epoch 43/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1074 - mae: 0.2365 - mse: 0.1074 - val_loss: 0.0701 - val_mae: 0.2207 - val_mse: 0.0701 - learning_rate: 0.0010
# Epoch 44/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1016 - mae: 0.2313 - mse: 0.1016 - val_loss: 0.0680 - val_mae: 0.2164 - val_mse: 0.0680 - learning_rate: 0.0010
# Epoch 45/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1110 - mae: 0.2466 - mse: 0.1110 - val_loss: 0.0690 - val_mae: 0.2186 - val_mse: 0.0690 - learning_rate: 0.0010
# Epoch 46/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0966 - mae: 0.2242 - mse: 0.0966 - val_loss: 0.0684 - val_mae: 0.2197 - val_mse: 0.0684 - learning_rate: 0.0010
# Epoch 47/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.1222 - mae: 0.2434 - mse: 0.1222 - val_loss: 0.0672 - val_mae: 0.2170 - val_mse: 0.0672 - learning_rate: 0.0010
# Epoch 48/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1336 - mae: 0.2557 - mse: 0.1336 - val_loss: 0.0676 - val_mae: 0.2175 - val_mse: 0.0676 - learning_rate: 0.0010
# Epoch 49/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.1030 - mae: 0.2265 - mse: 0.1030 - val_loss: 0.0686 - val_mae: 0.2189 - val_mse: 0.0686 - learning_rate: 0.0010
# Epoch 50/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1111 - mae: 0.2421 - mse: 0.1111 - val_loss: 0.0665 - val_mae: 0.2151 - val_mse: 0.0665 - learning_rate: 0.0010
# Epoch 51/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1181 - mae: 0.2456 - mse: 0.1181 - val_loss: 0.0677 - val_mae: 0.2169 - val_mse: 0.0677 - learning_rate: 0.0010
# Epoch 52/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1069 - mae: 0.2433 - mse: 0.1069 - val_loss: 0.0686 - val_mae: 0.2196 - val_mse: 0.0686 - learning_rate: 0.0010
# Epoch 53/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1117 - mae: 0.2388 - mse: 0.1117 - val_loss: 0.0656 - val_mae: 0.2169 - val_mse: 0.0656 - learning_rate: 0.0010
# Epoch 54/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0933 - mae: 0.2213 - mse: 0.0933 - val_loss: 0.0665 - val_mae: 0.2178 - val_mse: 0.0665 - learning_rate: 0.0010
# Epoch 55/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1063 - mae: 0.2350 - mse: 0.1063 - val_loss: 0.0665 - val_mae: 0.2184 - val_mse: 0.0665 - learning_rate: 0.0010
# Epoch 56/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1126 - mae: 0.2342 - mse: 0.1126 - val_loss: 0.0668 - val_mae: 0.2185 - val_mse: 0.0668 - learning_rate: 0.0010
# Epoch 57/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1109 - mae: 0.2400 - mse: 0.1109 - val_loss: 0.0677 - val_mae: 0.2207 - val_mse: 0.0677 - learning_rate: 0.0010
# Epoch 58/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1122 - mae: 0.2399 - mse: 0.1122 - val_loss: 0.0649 - val_mae: 0.2162 - val_mse: 0.0649 - learning_rate: 0.0010
# Epoch 59/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1094 - mae: 0.2295 - mse: 0.1094 - val_loss: 0.0671 - val_mae: 0.2206 - val_mse: 0.0671 - learning_rate: 0.0010
# Epoch 60/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1115 - mae: 0.2416 - mse: 0.1115 - val_loss: 0.0659 - val_mae: 0.2192 - val_mse: 0.0659 - learning_rate: 0.0010
# Epoch 61/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1047 - mae: 0.2342 - mse: 0.1047 - val_loss: 0.0664 - val_mae: 0.2208 - val_mse: 0.0664 - learning_rate: 0.0010
# Epoch 62/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0860 - mae: 0.2108 - mse: 0.0860 - val_loss: 0.0648 - val_mae: 0.2193 - val_mse: 0.0648 - learning_rate: 0.0010
# Epoch 63/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1026 - mae: 0.2200 - mse: 0.1026 - val_loss: 0.0664 - val_mae: 0.2220 - val_mse: 0.0664 - learning_rate: 0.0010
# Epoch 64/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1070 - mae: 0.2284 - mse: 0.1070 - val_loss: 0.0648 - val_mae: 0.2174 - val_mse: 0.0648 - learning_rate: 0.0010
# Epoch 65/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0992 - mae: 0.2237 - mse: 0.0992 - val_loss: 0.0668 - val_mae: 0.2227 - val_mse: 0.0668 - learning_rate: 0.0010
# Epoch 66/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0993 - mae: 0.2291 - mse: 0.0993 - val_loss: 0.0670 - val_mae: 0.2234 - val_mse: 0.0670 - learning_rate: 2.0000e-04
# Epoch 67/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0949 - mae: 0.2177 - mse: 0.0949 - val_loss: 0.0674 - val_mae: 0.2241 - val_mse: 0.0674 - learning_rate: 2.0000e-04
# Epoch 68/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1042 - mae: 0.2280 - mse: 0.1042 - val_loss: 0.0667 - val_mae: 0.2231 - val_mse: 0.0667 - learning_rate: 2.0000e-04
# Epoch 69/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0986 - mae: 0.2211 - mse: 0.0986 - val_loss: 0.0660 - val_mae: 0.2217 - val_mse: 0.0660 - learning_rate: 2.0000e-04
# Epoch 70/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1030 - mae: 0.2230 - mse: 0.1030 - val_loss: 0.0659 - val_mae: 0.2215 - val_mse: 0.0659 - learning_rate: 2.0000e-04
# Epoch 71/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0896 - mae: 0.2109 - mse: 0.0896 - val_loss: 0.0662 - val_mae: 0.2220 - val_mse: 0.0662 - learning_rate: 2.0000e-04
# Epoch 72/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1193 - mae: 0.2421 - mse: 0.1193 - val_loss: 0.0662 - val_mae: 0.2224 - val_mse: 0.0662 - learning_rate: 2.0000e-04
# Epoch 73/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1042 - mae: 0.2241 - mse: 0.1042 - val_loss: 0.0661 - val_mae: 0.2223 - val_mse: 0.0661 - learning_rate: 1.0000e-04
# Epoch 74/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1054 - mae: 0.2204 - mse: 0.1054 - val_loss: 0.0662 - val_mae: 0.2226 - val_mse: 0.0662 - learning_rate: 1.0000e-04
# Epoch 75/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0919 - mae: 0.2198 - mse: 0.0919 - val_loss: 0.0663 - val_mae: 0.2226 - val_mse: 0.0663 - learning_rate: 1.0000e-04
# Epoch 76/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0969 - mae: 0.2260 - mse: 0.0969 - val_loss: 0.0662 - val_mae: 0.2224 - val_mse: 0.0662 - learning_rate: 1.0000e-04
# Epoch 77/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1202 - mae: 0.2435 - mse: 0.1202 - val_loss: 0.0662 - val_mae: 0.2225 - val_mse: 0.0662 - learning_rate: 1.0000e-04
# Epoch 78/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0898 - mae: 0.2119 - mse: 0.0898 - val_loss: 0.0660 - val_mae: 0.2222 - val_mse: 0.0660 - learning_rate: 1.0000e-04
# Epoch 79/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0993 - mae: 0.2283 - mse: 0.0993 - val_loss: 0.0661 - val_mae: 0.2224 - val_mse: 0.0661 - learning_rate: 1.0000e-04
# Epoch 80/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1014 - mae: 0.2171 - mse: 0.1014 - val_loss: 0.0662 - val_mae: 0.2226 - val_mse: 0.0662 - learning_rate: 1.0000e-04
# Epoch 81/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0902 - mae: 0.2170 - mse: 0.0902 - val_loss: 0.0662 - val_mae: 0.2226 - val_mse: 0.0662 - learning_rate: 1.0000e-04
# Epoch 82/5000
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1000 - mae: 0.2170 - mse: 0.1000 - val_loss: 0.0658 - val_mae: 0.2220 - val_mse: 0.0658 - learning_rate: 1.0000e-04

# %% [markdown]
# Train the model

# %%
# plot the cureve for loss and val loss

import matplotlib.pyplot as plt
# Plot the loss and val_loss curves
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# MAKE PREDICTIONS

# %%
# load best model

from keras.models import load_model

# Load the best model
model = load_model('mpg_regressor.keras')

# %%
test_predictions=model.predict(X_test)
test_predictions[:5]
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# array([[ 0.03349413],
#        [-0.73355436],
#        [-0.5851574 ],
#        [ 1.3796343 ],
#        [-1.0559726 ]], dtype=float32)

# %% [markdown]
# EVALUATE THE MODEL USING MEAN SQUARED ERROR

# %%
loss,mae,mse=model.evaluate(X_test,y_test,verbose=0)
print('Testing mean squared error:MPG', format(mse))
# Out:
# Testing mean squared error:MPG 0.08791390806436539

# %%
# Reverse transform for the mpg i y_test and test_predictions using scaler1

import numpy as np
# Reverse transform for mpg in y_test and test_predictions using scaler2
y_test_original = scaler1.inverse_transform(np.array(y_test).reshape(-1, 1))
test_predictions_original = scaler1.inverse_transform(test_predictions)

print(y_test_original[:5])
print(test_predictions_original[:5])
# Out:
# [[21. ]
#  [18. ]
#  [21. ]
#  [36.1]
#  [18. ]]
# [[23.776033]
#  [17.78833 ]
#  [18.946741]
#  [34.284218]
#  [15.271483]]
